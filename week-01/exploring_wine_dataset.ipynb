# %% [markdown]
# # Exploring wine dataset (Explorando a base de dados de vinho)

# %% [markdown]
# ## Loading data (Carregando os dados)

# %%
import pandas as pd

# %%
filepath = 'data/Wine_Quality_Data.csv'
data = pd.read_csv(filepath)

# %%
data.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %%
data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
data.groupby('color').describe()
# Out:
#       alcohol                                                  chlorides  \
#         count       mean       std  min  25%   50%   75%   max     count
# color
# red    1599.0  10.422983  1.065668  8.4  9.5  10.2  11.1  14.9    1599.0
# white  4898.0  10.514267  1.230621  8.0  9.5  10.4  11.4  14.2    4898.0
#
#                  ...  total_sulfur_dioxide        volatile_acidity            \
#            mean  ...                   75%    max            count      mean
# color            ...
# red    0.087467  ...                  62.0  289.0           1599.0  0.527821
# white  0.045772  ...                 167.0  440.0           4898.0  0.278241
#
#
#             std   min   25%   50%   75%   max
# color
# red    0.179060  0.12  0.39  0.52  0.64  1.58
# white  0.100795  0.08  0.21  0.26  0.32  1.10
#
# [2 rows x 96 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(data.alcohol, data.chlorides, ls ='', marker='o')
